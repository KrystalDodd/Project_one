# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
from yelp.client import Client
import json
from ratelimit import limits
import requests
import csv
import random

df = pd.read_csv("../sub-est2019_all.csv", engine='python')
rural_city = df[(df["POPESTIMATE2019"]< 50000) & (df["POPESTIMATE2019"] > 1000)]
rural_df = rural_city[["NAME", "STNAME", "POPESTIMATE2019"]]
urban_city = df[df["POPESTIMATE2019"]>= 50000]
urban_df = urban_city[["NAME", "STNAME", "POPESTIMATE2019"]]
urban_index = urban_df.loc[urban_df["NAME"] == urban_df["STNAME"]].index
urban_clean = urban_df.drop(urban_index)
random_urban_city = urban_clean[["NAME", "STNAME","POPESTIMATE2019"]].sample(n=100, random_state=1)
random_rural_city = rural_df[["NAME", "STNAME", "POPESTIMATE2019"]].sample(n=100, random_state=1)
# Out:
#                    NAME      STNAME  POPESTIMATE2019
# 3374     Brentwood city  California            64474
# 75425    Lynchburg city    Virginia            82168
# 1595       Buckeye city     Arizona            79620
# 78253   Columbia County   Wisconsin            57532
# 55394  Springfield city        Ohio            58877

# %%
my_api_key = "replace"
headers = {'Authorization': 'Bearer %s' % my_api_key}

rural_citylist = []
url='https://api.yelp.com/v3/businesses/search'
 
for city in random_rural_city["NAME"]:
    params = {'location': city}
    req = requests.get(url, params = params, headers = headers).json()
    rural_citylist.append(req)

# %%
urban_citylist = []
url='https://api.yelp.com/v3/businesses/search'
 
for city in random_urban_city["NAME"]:
    params = {'location': city}
    req = requests.get(url, params = params, headers = headers).json()
    urban_citylist.append(req)

# %%
urban_dict = {}
rural_dict = {}

urban_dict["City"] = [urban_citylist[i]["businesses"][i]["location"]["city"] for i in range(3)]
# urban_dict["City"] = [urban_citylist[i]["location"]["city"] for i in range(len(urban_citylist))]
# urban_dict["State"] = [urban_citylist[i]["location"]["state"] for i in range(len(urban_citylist))]

# %%
print(len(urban_citylist))
# Out:
# 100

# %%
print(urban_dict)
# Out:
# {'City': ['Brentwood', 'Lynchburg', 'Buckeye']}

# %%
print(urban_citylist)
# Out:
# [{'businesses': [{'id': 'JY4bXZZKXPd6TdB9G3skPw', 'alias': 'dinos-sandwich-shop-brentwood', 'name': "Dino's Sandwich Shop", 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ms5U-PbzTmYlhHlvrW-sYg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/dinos-sandwich-shop-brentwood?adjust_creative=-4RAoLyBIo0ezRYE9TBNPw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-4RAoLyBIo0ezRYE9TBNPw', 'review_count': 373, 'categories': [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'salad', 'title': 'Salad'}], 'rating': 4.5, 'coordinates': {'latitude': 37.9328, 'longitude': -121.69549}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '729 1st St', 'address2': '', 'address3': '', 'city': 'Brentwood', 'zip_code': '94513', 'country': 'US', 'state': 'CA', 'display_address': ['729 1st St', 'Brentwood, CA 94513']}, 'phone': '+19256847248', 'display_phone': '(925) 684-7248', 'distance': 1095.1014125103154}, {'id': 'rk5oNSs45ILW-2tofykRXQ', 'alias': 'zephyr-grill-and-bar-brentwood', 'name': 'Zephyr Grill & Bar', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P7GIUawl_4P_1qYAV9t4sg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/zephyr-grill-and-bar-brentwood?adjust_creative=-4RAoLyBIo0ezRYE9TBNPw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-4RAoLyBIo0ezRYE9TBNPw', 'review_count': 687, 'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}], 'rating': 4.0, 'coordinates': {'latitude': 37.9317, 'longitude': -121.69451}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '613 1st St', 'address2': 'Ste 100', 'address3': '', 'city': 'Brentwood', 'zip_code': '94513', 'country': 'US', 'state': 'CA', 'display_address': ['613 1st St', 'Ste 100', 'Brentwood, CA 94513']}, 'phone': '+19254184708', 'display_phone': '(925) 418-4708', 'distance': 1247.0546443043365}, {'id': 'xsIrPuoXwLeM02QDUYfN4w', 'alias': 'big-house-beans-brentwood-3', 'name': 'Big House Beans', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XOcZKzw7oZEYgtMgMhoqLg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/big-house-beans-brentwood-3?adjust_creative=-4RAoLyBIo0ezRYE9TBNPw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-4RAoLyBIo0ezRYE9TBNPw', 'review_count': 173, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}], 'rating': 4.5, 'coordinates': {'latitude': 37.93722, 'longitude': -121.69877}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1155 2nd St', 'address2': 'Ste A', 'address3': None, 'city': 'Brentwood', 'zip_code': '94513', 'country': 'US', 'state': 'CA', 'display_address': ['1155 2nd St', 'Ste A', 'Brentwood, CA 94513']}, 'phone': '+19256797687', 'display_phone': '(925) 679-7687', 'distance': 686.1021085092949}, {'id': 'tSQGBILYpFo1r0RlZNi6CA', 'alias': 'enishi-kitchen-brentwood-4', 'name': 'Enishi Kitchen', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3U5BpmO3DmcmJ6kwIa5MTw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/enishi-kitchen-brentwood-4?adjust_creative=-4RAoLyBIo0ezRYE9TBNPw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-4RAoLyBIo0ezRYE9TBNPw', 'review_count': 431, 'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'japanese', 'title': 'Japanese'}], 'rating': 4.0, 'coordinates': {'latitude': 37.925922, 'longitude': -121.697432}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '4441 Balfour Rd', 'address2': 'Ste A', 'address3': '', 'city': 'Brentwood', 'zip_code': '94513', 'country': 'US', 'state': 'CA', 'display_address': ['4441 Balfour Rd', 'Ste A', 'Brentwood, CA 94513']}, 'phone': '+19252401358', 'display_phone': '(925) 240- ...
