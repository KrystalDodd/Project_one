# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
#from yelp.client import Client
import json
from ratelimit import limits
import requests
import csv
import random
from lock import yelp_key
my_api_key = yelp_key


df = pd.read_csv("../sub-est2019_all.csv", engine='python')
rural_city = df[(df["POPESTIMATE2019"]< 50000) & (df["POPESTIMATE2019"] > 1000) & (df["PRIMGEO_FLAG"]==0)]
rural_df = rural_city[["NAME", "STNAME", "POPESTIMATE2019"]]
urban_city = df[df["POPESTIMATE2019"]>= 50000]
urban_df = urban_city[["NAME", "STNAME", "POPESTIMATE2019"]]
urban_index = urban_df.loc[urban_df["NAME"] == urban_df["STNAME"]].index
urban_clean = urban_df.drop(urban_index)
random_urban_city = urban_clean[["NAME", "STNAME","POPESTIMATE2019"]].sample(n=100, random_state=1)
random_rural_city = rural_df[["NAME", "STNAME", "POPESTIMATE2019"]].sample(n=100, random_state=1)

# %%
headers = {'Authorization': 'Bearer %s' % my_api_key}

rural_dict = {
    "Searched": [],
    "City": [],
    "State": [],
    "Lat": [],
    "Lng": [],
    "Restaurant": [],
    "Category": [],
#     "Category 2": [],
#     "Category 3": [],
    "Transactions":[]
}

url='https://api.yelp.com/v3/businesses/search'
offset = np.arange(0,950,50).tolist() 

for city, state in zip(random_rural_city["NAME"], random_rural_city["STNAME"]):
    for i in range(len(offset)):
        params = {
            'location': f"{city}, {state}",
            'radius': 8047,
            'limit': 50,
            'offset': offset[i]
                 }
        response = requests.get(url, params = params, headers = headers).json()
        try:
            for business in range(len(response["businesses"])):
                try:
                    rural_dict["Searched"].append(f"{city}, {state}")
                    rural_dict["City"].append(response["businesses"][business]["location"]["city"])
                    rural_dict["State"].append(response["businesses"][business]["location"]["state"])
                    rural_dict["Lat"].append(response["businesses"][business]["coordinates"]["latitude"])
                    rural_dict["Lng"].append(response["businesses"][business]["coordinates"]["longitude"])
                    rural_dict["Restaurant"].append(response["businesses"][business]["name"])
                    rural_dict["Category"].append([response["businesses"][business]["categories"][i]["title"] for i in range(len(response["businesses"][business]["categories"]))])
#                     rural_dict["Category"].append(response["businesses"][business]["categories"][0]["title"])
#                     rural_dict["Category 2"].append(response["businesses"][business]["categories"][1]["title"])
#                     rural_dict["Category 3"].append(response["businesses"][business]["categories"][2]["title"])
                    rural_dict["Transactions"].append(response["businesses"][business]["transactions"])
                except KeyError:
                    rural_dict["Searched"].append("No City Found")
                    rural_dict["City"].append("No City Found")
                    rural_dict["State"].append("No State Found")
                    rural_dict["Lat"].append("No Lat Found")
                    rural_dict["Lng"].append("No Lng Found")
                    rural_dict["Restaurant"].append("No Restaurant Found")
                    rural_dict["Category"].append("No Categories")
                    rural_dict["Transactions"].append("No Transactions Found")
#                 except IndexError:
#                     rural_dict["Category 2"].append("")
#                     rural_dict["Category 3"].append("")
        except KeyError:
                pass

# %%
rural = pd.DataFrame.from_dict(rural_dict, orient='index')
rural = rural.transpose()
rural.head(70)

# %%
headers = {'Authorization': 'Bearer %s' % my_api_key}

urban_dict = {
    "Searched": [],
    "City": [],
    "State": [],
    "Lat": [],
    "Lng": [],
    "Restaurant": [],
    "Category": [],
#     "Category 2": [],
#     "Category 3": [],
    "Transactions":[]
}

url='https://api.yelp.com/v3/businesses/search'
offset = np.arange(0,950,50).tolist() 

for city, state in zip(random_urban_city["NAME"], random_urban_city["STNAME"]):
    for i in range(len(offset)):
        params = {
            'location': f"{city}, {state}",
            'radius': 8047,
            'limit': 50,
            'offset': offset[i]
                 }
        response = requests.get(url, params = params, headers = headers).json()
        try:
            for business in range(len(response["businesses"])):
                try:
                    urban_dict["Searched"].append(f"{city}, {state}")
                    urban_dict["City"].append(response["businesses"][business]["location"]["city"])
                    urban_dict["State"].append(response["businesses"][business]["location"]["state"])
                    urban_dict["Lat"].append(response["businesses"][business]["coordinates"]["latitude"])
                    urban_dict["Lng"].append(response["businesses"][business]["coordinates"]["longitude"])
                    urban_dict["Restaurant"].append(response["businesses"][business]["name"])
                    urban_dict["Category"].append([response["businesses"][business]["categories"][i]["title"] for i in range(len(response["businesses"][business]["categories"]))])
#                     rural_dict["Category"].append(response["businesses"][business]["categories"][0]["title"])
#                     rural_dict["Category 2"].append(response["businesses"][business]["categories"][1]["title"])
#                     rural_dict["Category 3"].append(response["businesses"][business]["categories"][2]["title"])
                    urban_dict["Transactions"].append(response["businesses"][business]["transactions"])
                except KeyError:
                    urban_dict["Searched"].append("No City Found")
                    urban_dict["City"].append("No City Found")
                    urban_dict["State"].append("No State Found")
                    urban_dict["Lat"].append("No Lat Found")
                    urban_dict["Lng"].append("No Lng Found")
                    urban_dict["Restaurant"].append("No Restaurant Found")
                    urban_dict["Category"].append("No Categories")
                    urban_dict["Transactions"].append("No Transactions Found")
#                 except IndexError:
#                     rural_dict["Category 2"].append("")
#                     rural_dict["Category 3"].append("")
        except KeyError:
                pass

# %%
urban = pd.DataFrame.from_dict(urban_dict, orient='index')
urban = urban.transpose()
urban.head()
# Out:
# Empty DataFrame
# Columns: [Searched, City, State, Lat, Lng, Restaurant, Category, Transactions]
# Index: []

# %%
urban.to_csv("../urbantest.csv")
#rural.to_csv("../ruraltest.csv")

# %%
rural_cat= pd.DataFrame(rural["Category"].to_list(), columns = ["Category 1", "Category 2", "Category 3", "Category 4", "Category 5", "Category 6"])
rural_clean = rural_cat[["Category 1", "Category 2", "Category 3"]]
rural_clean = rural.merge(rural_cat, left_index = True,right_index = True)
rural_clean.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b5c2a4217caa> in <module>
# ----> 1 rural_cat= pd.DataFrame(rural["Category"].to_list(), columns = ["Category 1", "Category 2", "Category 3", "Category 4", "Category 5", "Category 6"])
#       2 rural_clean = rural_cat[["Category 1", "Category 2", "Category 3"]]
#       3 rural_clean = rural.merge(rural_cat, left_index = True,right_index = True)
#       4 rural_clean.head()
#
# NameError: name 'rural' is not defined

# %%
urban_cat= pd.DataFrame(urban["Category"].to_list(), columns = ["Category 1", "Category 2", "Category 3", "Category 4"], index = urban.index)
urban_cats = urban_cat[["Category 1", "Category 2", "Category 3"]]
urban_clean = urban.merge(urban_cats, left_index = True,right_index = True)
urban_clean.head(30)

# %%
path = (r"C:\Users\yenia\Desktop\JHU_Bootcamp\Project_1\Project_one\Data Pull\urban_clean.csv")
urban_clean = pd.read_csv(path)

# %%
urban_clean.count()
# Out:
# Unnamed: 0      47156
# Searched        47156
# City            47156
# State           47156
# Lat             47153
# Lng             47153
# Restaurant      47156
# Category        47156
# Transactions    47156
# Category 1      47154
# Category 2      30492
# Category 3      16865
# dtype: int64

# %%
total_all = len(urban_clean["Searched"])
print(total_all)
# Out:
# 47156

# %%
#vegan = urban_clean[list(urban_clean.loc[:,"Category 1": "Category 3"] == "Vegan")]
#vegan_1 = urban_clean[urban_clean['Category 1'] == 'Vegan']
#df[ list(df.loc[:,'A':'C']) + ['E'] + list(df.loc[:,'G':'I']) ]
keywords = ["Vegan", "vegan"]
urban_vegan = urban_clean[(urban_clean["Category 1"].isin(keywords))|(urban_clean["Category 2"].isin(keywords))|(urban_clean["Category 3"].isin(keywords))]
urban_vegan_df = pd.DataFrame(urban_vegan)
urban_vegan_df.head()
# Out:
#      Unnamed: 0                    Searched       City State        Lat  \
# 321         321  Oceanside city, California  Oceanside    CA  33.175745
# 340         340  Oceanside city, California  Oceanside    CA  33.196250
# 408         408  Oceanside city, California  Oceanside    CA  33.183085
# 923         923  Oceanside city, California   Carlsbad    CA  33.138800
# 985         985  Oceanside city, California   Carlsbad    CA  33.139909
#
#             Lng              Restaurant  \
# 321 -117.363002                The Plot
# 340 -117.379320  Rim Talay Thai Cuisine
# 408 -117.331893                Everbowl
# 923 -117.272360       Plantiful Kitchen
# 985 -117.272801          Choice Juicery
#
#                                               Category  \
# 321                        ['Vegan', 'American (New)']
# 340                   ['Thai', 'Vegan', 'Gluten-Free']
# 408  ['Acai Bowls', 'Juice Bars & Smoothies', 'Vegan']
# 923                  ['Bakeries', 'Vegan', 'Desserts']
# 985                ['Vegan', 'Juice Bars & Smoothies']
#
#                Transactions  Category 1              Category 2   Category 3
# 321            ['delivery']       Vegan          American (New)          NaN
# 340            ['delivery']        Thai                   Vegan  Gluten-Free
# 408  ['pickup', 'delivery']  Acai Bowls  Juice Bars & Smoothies        Vegan
# 923                      []    Bakeries                   Vegan     Desserts
# 985  ['delivery', 'pickup']       Vegan  Juice Bars & Smoothies          NaN

# %%
urban_vegan_df.count()
# Out:
# Unnamed: 0      331
# Searched        331
# City            331
# State           331
# Lat             331
# Lng             331
# Restaurant      331
# Category        331
# Transactions    331
# Category 1      331
# Category 2      317
# Category 3      270
# dtype: int64

# %%
urban_vegan_df.describe()
# Out:
#          Unnamed: 0         Lat         Lng
# count    331.000000  331.000000  331.000000
# mean   26477.069486   35.449038  -96.655201
# std    13271.358055    5.256771   20.021570
# min      321.000000   25.736019 -122.492114
# 25%    14598.500000   33.201742 -118.144691
# 50%    28508.000000   36.131644  -88.208500
# 75%    38279.000000   39.726137  -80.136308
# max    47135.000000   43.095812  -70.879084

# %%
total_urban_vegan = len(urban_vegan["Searched"])
total_urban_vegan
# Out:
# 331

# %%
urban_clean_opt = urban_clean
urban_clean_opt["Vegan Options"] = ""
urban_clean_opt.head()
urban_clean_opt["Vegan Options"] = np.where(urban_vegan["Category 1"].isin(keywords)|urban_vegan["Category 2"].isin(keywords)|urban_vegan["Category 3"].isin(keywords), True, False)
urban_clean_opt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-19b77823c48f> in <module>
#       2 urban_clean_opt["Vegan Options"] = ""
#       3 urban_clean_opt.head()
# ----> 4 urban_clean_opt["Vegan Options"] = np.where(urban_vegan["Category 1"].isin(keywords)|urban_vegan["Category 2"].isin(keywords)|urban_vegan["Category 3"].isin(keywords), True, False)
#       5 urban_clean_opt
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
urban_clean_opt.count()
# Out:
# Unnamed: 0       331
# Searched         331
# City             331
# State            331
# Lat              331
# Lng              331
# Restaurant       331
# Category         331
# Transactions     331
# Category 1       331
# Category 2       317
# Category 3       270
# Vegan Options    331
# dtype: int64

# %%
urban_grouped= urban_clean_opt.groupby("Searched").count()
urban_grouped
# Out:
#                                  Unnamed: 0  City  State  Lat  Lng  \
# Searched
# Alameda city, California                950   950    950  950  950
# Anderson city, Indiana                  152   152    152  152  152
# Arcadia city, California                950   950    950  950  950
# Aurora city, Illinois                   423   423    423  423  423
# Battle Creek city, Michigan             196   196    196  196  196
# ...                                     ...   ...    ...  ...  ...
# Wichita city, Kansas                    598   598    598  598  598
# Windsor County, Vermont                   7     7      7    7    7
# Woodbridge township, New Jersey         950   950    950  950  950
# Woodbury city, Minnesota                222   222    222  222  222
# Yuba County, California                   8     8      8    8    8
#
#                                  Restaurant  Category  Transactions  \
# Searched
# Alameda city, California                950       950           950
# Anderson city, Indiana                  152       152           152
# Arcadia city, California                950       950           950
# Aurora city, Illinois                   423       423           423
# Battle Creek city, Michigan             196       196           196
# ...                                     ...       ...           ...
# Wichita city, Kansas                    598       598           598
# Windsor County, Vermont                   7         7             7
# Woodbridge township, New Jersey         950       950           950
# Woodbury city, Minnesota                222       222           222
# Yuba County, California                   8         8             8
#
#                                  Category 1  Category 2  Category 3  \
# Searched
# Alameda city, California                950         651         350
# Anderson city, Indiana                  152          82          44
# Arcadia city, California                950         699         410
# Aurora city, Illinois                   423         256         135
# Battle Creek city, Michigan             196         118          54
# ...                                     ...         ...         ...
# Wichita city, Kansas                    598         335         169
# Windsor County, Vermont                   7           7           5
# Woodbridge township, New Jersey         950         586         301
# Woodbury city, Minnesota                222         144          85
# Yuba County, California                   8           6           1
#
#                                  Vegan Options
# Searched
# Alameda city, California                   950
# Anderson city, Indiana                     152
# Arcadia city, California                   950
# Aurora city, Illinois                      423
# Battle Creek city, Michigan                196
# ...                                        ...
# Wichita city, Kansas                       598
# Windsor County, Vermont                      7
# Woodbridge township, New Jersey            950
# Woodbury city, Minnesota                   222
# Yuba County, California                      8
#
# [95 rows x 12 columns]

# %%
urban_count_df = pd.DataFrame(urban_grouped_count)
del urban_count_df["Unnamed: 0"]
urban_count_df
# Out:
#                                  City  State  Lat  Lng  Restaurant  Category  \
# Searched
# Alameda city, California           17     17   17   17          17        17
# Arcadia city, California            6      6    6    6           6         6
# Bellflower city, California         7      7    7    7           7         7
# Berkeley city, California          27     27   27   27          27        27
# Bradenton city, Florida             1      1    1    1           1         1
# Brookhaven city, Georgia            9      9    9    9           9         9
# Cambridge city, Massachusetts      25     25   25   25          25        25
# Carmel city, Indiana                2      2    2    2           2         2
# Champaign city, Illinois            2      2    2    2           2         2
# Chesapeake city, Virginia           4      4    4    4           4         4
# Chico city, California              4      4    4    4           4         4
# Cincinnati city, Ohio               8      8    8    8           8         8
# Citrus Heights city, California     9      9    9    9           9         9
# Colonie town, New York              4      4    4    4           4         4
# Daly City city, California          4      4    4    4           4         4
# Denton city, Texas                  6      6    6    6           6         6
# Doral city, Florida                18     18   18   18          18        18
# Dundee township, Illinois           1      1    1    1           1         1
# Durham city, North Carolina        11     11   11   11          11        11
# Elk Grove city, California          3      3    3    3           3         3
# Fairfield township, Indiana         1      1    1    1           1         1
# Fall River city, Massachusetts      1      1    1    1           1         1
# Hollywood city, Florida            16     16   16   16          16        16
# Hoover city, Alabama                1      1    1    1           1         1
# Lowell city, Massachusetts          3      3    3    3           3         3
# Lyons township, Illinois            1      1    1    1           1         1
# Madison city, Alabama               1      1    1    1           1         1
# New Rochelle city, New York         4      4    4    4           4         4
# Newport Beach city, California     19     19   19   19          19        19
# Norwalk city, Connecticut           3      3    3    3           3         3
# Oceanside city, California          5      5    5    5           5         5
# Passaic city, New Jersey            5      5    5    5           5         5
# Peabody city, Massachusetts         4      4    4    4           4         4
# Peoria city, Arizona                2      2    2    2           2         2
# Perry township, Indiana             1      1    1    1           1         1
# Perth Amboy city, New Jersey        3      3    3    3           3         3
# Plainfield city, New Jersey         4      4    4    4           4         4
# Pleasanton city, California         4      4    4    4           4         4
# Proviso township, Illinois          5      5    5    5           5         5
# Rock Hill city, South Carolina      2      2    2    2           2         2
# Santa Barbara city, California     10     10   10   10          10        10
# Sarasota city, Florida              9      9    9    9           9         9
# Simi Valley city, California        2      2    2    2           2         2
# Springfield city, Missouri          1      1    1    1           1         1
# Stonecrest city, Georgia            1      1    1    1           1         1
# Sunrise city, Florida               9      9    9    9           9         9
# Taylorsville city, Utah             5      5    5    5           5         5
# Travis County, Texas               22     22   22   22          22        22
# Tulsa city, Oklahoma                1      1    1    1           1         1
# Utica city, New York                2      2    2    2           2         2
# Warner Robins city, Georgia         1      1    1    1           1         1
# West Covina city, California        7      7    7    7           7         7
# Wichita city, Kansas                2      2    2    2           2         2
# Woodbridge township, New Jersey     6      6    6    6           6         6
#
#                                  Transactions  Category 1  Category 2  \
# Searched
# Alameda city, California                   17          17          16
# Arcadia city, California                    6           6           5
# Bellflower city, California                 7           7           7
# Berkeley city, California                  27          27          27
# Bradenton city, Florida                     1           1           1
# Brookhaven city, Georgia                    9           9           7
# Cambridge city, Massachusetts              25          25          23
# Carmel city, Indiana                        2           2           2
# Champaign city, Illinois                    2           2           2
# Chesapeake city, Virginia                   4           4           3
# Chico city, California                      4           4           4
# Cincinnati city, Ohio                       8           8           8
# Citrus Heights city, California             9           9           8
# Colonie town, New York                      4           4           4
# Daly City city, California                  4           4           4
# Denton city, Texas                          6           6           5
# Doral city, Florida                        18          18          18
# Dundee township, Illinois                   1           1           1
# Durham city, North Carolina                11          11          11
# Elk Grove city, California                  3           3           3
# Fairfield township, Indiana                 1           1           1
# Fall River city, Massachusetts              1           1           1
# Hollywood city, Florida                    16          16          14
# Hoover city, Alabama                        1           1           1
# Lowell city, Massachusetts                  3           3           3
# Lyons township, Illinois                    1           1           1
# Madison city, Alabama                       1           1           1
# New Rochelle city, New York                 4           4           4
# Newport Beach city, California             19          19          18
# Norwalk city, Connecticut                   3           3           3
# Oceanside city, California                  5           5           5
# Passaic city, New Jersey                    5           5           5
# Peabody city, Massachusetts                 4           4           4
# Peoria city, Arizona                        2           2           2
# Perry township, Indiana                     1           1           1
# Perth Amboy city, New Jersey                3           3           3
# Plainfield city, New Jersey                 4           4           4
# Pleasanton city, California                 4           4           3
# Proviso township, Illinois                  5           5           5
# Rock Hill city, South Carolina              2           2           2
# Santa Barbara city, California             10          10           9
# Sarasota city, Florida                      9           9           9
# Simi Valley city, California                2           2           2
# Springfield city, Missouri                  1           1           1
# Stonecrest city, Georgia                    1           1           1
# Sunrise city, Florida                       9           9           9
# Taylorsville city, Utah                     5           5           5
# Travis County, Texas                       22          22          22
# Tulsa city, Oklahoma                        1           1           1
# Utica city, New York                        2           2           2
# Warner Robins city, Georgia                 1           1           1
# West Covina city, California                7           7           7
# Wichita city, Kansas                        2           2           2
# Woodbridge township, New Jersey             6           6           6
#
#                                  Category 3  Vegan Options
# Searched
# Alameda city, California                 14             17
# Arcadia city, California                  5              6
# Bellflower city, California               7              7
# Berkeley city, California                22             27
# Bradenton city, Florida                   1              1
# Brookhaven city, Georgia                  7              9
# Cambridge city, Massachusetts            18             25
# Carmel city, Indiana                      2              2
# Champaign city, Illinois                  2              2
# Chesapeake city, Virginia                 2              4
# Chico city, California                    4              4
# Cincinnati city, Ohio                     8              8
# Citrus Heights city, California           7              9
# Colonie town, New York                    3              4
# Daly City city, California                4              4
# Denton city, Texas                        4              6
# Doral city, Florida                      16             18
# Dundee township, Illinois                 1              1
# Durham city, North Carolina              10             11
# Elk Grove city, California                1              3
# Fairfield township, Indiana               1              1
# Fall River city, Massachusetts            1              1
# Hollywood city, Florida                  11             16
# Hoover city, Alabama                      1              1
# Lowell city, Massachusetts                3              3
# Lyons township, Illinois                  1              1
# Madison city, Alabama                     1              1
# New Rochelle city, New York               2              4
# Newport Beach city, California           16             19
# Norwalk city, Connecticut                 2              3
# Oceanside city, California                3              5
# Passaic city, New Jersey                  4              5
# Peabody city, Massachusetts               4              4
# Peoria city, Arizona                      2              2
# Perry township, Indiana                   0              1
# Perth Amboy city, New Jersey              2              3
# Plainfield city, New Jersey               3              4
# Pleasanton city, California               2              4
# Proviso township, Illinois                5              5
# Rock Hill city, South Carolina            2              2
# Santa Barbara city, California            8             10
# Sarasota city, Florida                    9              9
# Simi Valley city, California              1              2
# Springfield city, Missouri                0              1
# Stonecrest city, Georgia                  1              1
# Sunrise city, Florida                     8              9
# Taylorsville city, Utah                   4              5
# Travis County, Texas                     17             22
# Tulsa city, Oklahoma                      1              1
# Utica city, New York                      2              2
# Warner Robins city, Georgia               1              1
# West Covina city, California              7              7
# Wichita city, Kansas                      2              2
# Woodbridge township, New Jersey           5              6

# %%
urban_count_df.to_csv("../urbangroupedcount.csv")

# %%
urban_count_df.describe()
# Out:
#        Unnamed: 0       City      State        Lat        Lng  Restaurant  \
# count   54.000000  54.000000  54.000000  54.000000  54.000000   54.000000
# mean     6.129630   6.129630   6.129630   6.129630   6.129630    6.129630
# std      6.381123   6.381123   6.381123   6.381123   6.381123    6.381123
# min      1.000000   1.000000   1.000000   1.000000   1.000000    1.000000
# 25%      2.000000   2.000000   2.000000   2.000000   2.000000    2.000000
# 50%      4.000000   4.000000   4.000000   4.000000   4.000000    4.000000
# 75%      7.750000   7.750000   7.750000   7.750000   7.750000    7.750000
# max     27.000000  27.000000  27.000000  27.000000  27.000000   27.000000
#
#         Category  Transactions  Category 1  Category 2  Category 3  \
# count  54.000000     54.000000   54.000000   54.000000   54.000000
# mean    6.129630      6.129630    6.129630    5.870370    5.000000
# std     6.381123      6.381123    6.381123    6.136947    5.154225
# min     1.000000      1.000000    1.000000    1.000000    0.000000
# 25%     2.000000      2.000000    2.000000    2.000000    1.250000
# 50%     4.000000      4.000000    4.000000    4.000000    3.000000
# 75%     7.750000      7.750000    7.750000    7.000000    7.000000
# max    27.000000     27.000000   27.000000   27.000000   22.000000
#
#        Vegan Options
# count      54.000000
# mean        6.129630
# std         6.381123
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         7.750000
# max        27.000000

# %%
total_vegan = sum(urban_count_df["Vegan Options"])
total_vegan
# Out:
# 331

# %%
df["Searched"] = df["NAME"] + ", " + df["STNAME"]

#rural_clean_pop = pd.merge(rural_clean, df[["POPESTIMATE2019", "Searched"]],  how='left', on= "Searched")
urban_clean_pop = pd.merge(urban_clean, df[["POPESTIMATE2019", "Searched"]],  how='left', on= "Searched")
urban_clean_pop
# Out:
#         Unnamed: 0                         Searched            City State  \
# 0                0  Spokane Valley city, Washington  Spokane Valley    WA
# 1                0  Spokane Valley city, Washington  Spokane Valley    WA
# 2                1  Spokane Valley city, Washington  Spokane Valley    WA
# 3                1  Spokane Valley city, Washington  Spokane Valley    WA
# 4                2  Spokane Valley city, Washington  Spokane Valley    WA
# ...            ...                              ...             ...   ...
# 112628       47151             Peoria city, Arizona        Maricopa    AZ
# 112629       47152             Peoria city, Arizona         Phoenix    AZ
# 112630       47153             Peoria city, Arizona      Scottsdale    AZ
# 112631       47154             Peoria city, Arizona  San Tan Valley    AZ
# 112632       47155             Peoria city, Arizona      Greenville    PA
#
#               Lat         Lng                   Restaurant  \
# 0       47.656965 -117.278017           La Plaza De Mexico
# 1       47.656965 -117.278017           La Plaza De Mexico
# 2       47.657224 -117.261841             Choo Choo Tortas
# 3       47.657224 -117.261841             Choo Choo Tortas
# 4       47.613473 -117.243869               Craft & Gather
# ...           ...         ...                          ...
# 112628  33.068770 -112.002080  Maricopa Outdoor Adventures
# 112629  33.453766 -112.073967          Tropic Like Its Hot
# 112630  33.510676 -111.895378              Mobile Marinara
# 112631  33.151720 -111.563040                   Nonla Viet
# 112632  41.404499  -80.391179              Shaffer's Cakes
#
#                                            Category  Transactions  \
# 0                                       ['Mexican']  ['delivery']
# 1                                       ['Mexican']  ['delivery']
# 2                                       ['Mexican']  ['delivery']
# 3                                       ['Mexican']  ['delivery']
# 4                ['American (Traditional)', 'Bars']            []
# ...                                             ...           ...
# 112628         ['Hiking', 'Tours', 'Rock Climbing']            []
# 112629       ['Food Trucks', 'Desserts', 'Burgers']            []
# 112630  ['Chicken Wings', 'Italian', 'Food Trucks']            []
# 112631                ['Vietnamese', 'Food Trucks']            []
# 112632     ['Bakeries', 'Custom Cakes', 'Cupcakes']            []
#
#                     Category 1    Category 2     Category 3 Vegan Options  \
# 0                      Mexican           NaN            NaN
# 1                      Mexican           NaN            NaN
# 2                      Mexican           NaN            NaN
# 3                      Mexican           NaN            NaN
# 4       American (Traditional)          Bars            NaN
# ...                        ...           ...            ...           ...
# 112628                  Hiking         Tours  Rock Climbing
# 112629             Food Trucks      Desserts        Burgers
# 112630           Chicken Wings       Italian    Food Trucks
# 112631              Vietnamese   Food Trucks            NaN
# 112632                Bakeries  Custom Cakes       Cupcakes
#
#         POPESTIMATE2019
# 0                101060
# 1                101060
# 2                101060
# 3                101060
# 4                101060
# ...                 ...
# 112628           175961
# 112629           175961
# 112630           175961
# 112631           175961
# 112632           175961
#
# [112633 rows x 14 columns]
