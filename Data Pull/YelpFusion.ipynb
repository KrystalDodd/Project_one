# %%
Client ID
4zEh1ADDooX8vpBk0GH0iQ

API Key
Q4VMm1uRj7KeIvqc1IS8e4DxqWqzoNyUCY_tvE9M5eql9ZPlcsNkyYfW3z9_CUNIOa_3zRAdCc29_6UxqtV4MKWRupjUkhdJPMjMqdR_mRR7fVZC6GnYmodrBj_IX3Yx

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
#from scipy.stats import linregress
#from config import api_key
import json

# Import API key
#from api_keys import 

api_key = "Q4VMm1uRj7KeIvqc1IS8e4DxqWqzoNyUCY_tvE9M5eql9ZPlcsNkyYfW3z9_CUNIOa_3zRAdCc29_6UxqtV4MKWRupjUkhdJPMjMqdR_mRR7fVZC6GnYmodrBj_IX3Yx"

headers = {'Authorization': 'Bearer %s' % api_key}

url='https://api.yelp.com/v3/businesses/search'
 
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'vegan','location':'New York City'}

# Making a get request to the API
req=requests.get(url, params=params, headers=headers)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))

# printing the text from the response 
json.loads(req.text)
# Out:
# The status code is 200
# {'businesses': [{'id': 'MTP9i2rqkZf1Tn8-ARTPNA',
#    'alias': 'guevaras-brooklyn',
#    'name': "Guevara's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pJByPalgpnXrH5yI3XXUBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guevaras-brooklyn?adjust_creative=4zEh1ADDooX8vpBk0GH0iQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4zEh1ADDooX8vpBk0GH0iQ',
#    'review_count': 31,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.688019, 'longitude': -73.962881},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '39 Clifton Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 Clifton Pl', 'Brooklyn, NY 11238']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3281.387147995623},
# ...
